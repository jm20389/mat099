# %%
# PRNU test using serialized korus dataset

from classes import *

stats_cc, stats_pce, fingerprints = PRNUProcessor.testPRNU(ff_dir =  'data/ff-jpg/*.JPG',
                                                           #ff_dir =  'datasets/data-korus/serialized/flatfield/*.TIF',
                                                           nat_dir = 'datasets/data-korus/serialized/natural/*.TIF')
# Out:
# Computing fingerprints
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 # PRNU test using serialized korus dataset
#       3 from classes import *
# ----> 5 stats_cc, stats_pce, fingerprints = PRNUProcessor.testPRNU(ff_dir =  'data/ff-jpg/*.JPG',
#       6                                                            #ff_dir =  'datasets/data-korus/serialized/flatfield/*.TIF',
#       7                                                            nat_dir = 'datasets/data-korus/serialized/natural/*.TIF')
#
# File ~/mat099/classes/PRNUProcessor.py:574, in PRNUProcessor.testPRNU(ff_dir, nat_dir)
#     571         imgs += [im_cut]
#     572     k += [PRNUProcessor.extract_multiple_aligned(imgs, processes=cpu_count())]
# --> 574 k = np.stack(k, 0)
#     576 print('Computing residuals')
#     578 imgs = []
#
# ...

# %%
type(fingerprints[0])

plt.imshow(fingerprints[0])
