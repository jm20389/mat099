# %% [markdown]
# ### Dataset </br>
# Test with a not demanding picture dataset (minst), black and white pictures

# %%
from classes import *

mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %% [markdown]
# ### Run picture generation test </br>

# %%
# GAN test
myModel = GanBuilder(np.array(X_train), Y_train, np.array(X_test), Y_test, train_dir = 'output/gan_images_test02/', epochs=4000)
myModel.build_generator()
myModel.build_discriminator()

myModel.compile()
myModel.train()

# %%
picture_path = "output/gan_images_test02/3800.png" # latest iteration
image = Image.open(picture_path)

plt.imshow(image)
plt.show()
