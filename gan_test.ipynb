# %%
from classes import * # Wrappers package for the project - PRNUProcessor, DatasetProcessor, ImageProcessor, ModelBuilder, PickleHandler

import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split

mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
#pics_bw = [PRNUProcessor.rgb2gray(pic) for pic in pics]
# Out:
# 2023-08-15 22:30:35.782243: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-15 22:30:35.825094: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-15 22:30:35.826090: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-15 22:30:36.618981: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Dataset </br>
# Test with a not demanding picture dataset (minst), black and white pictures

# %%
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
#X_train, X_test, y_train, y_test = train_test_split(pics_bw[:240], camera_model, test_size=0.2, random_state=42)

# %% [markdown]
# ### Run picture generation test </br>
# Pictures saved to /gan_images2

# %%
# GAN test

import numpy as np
myModel = GanBuilder(np.array(X_train), Y_train, np.array(X_test), Y_test)
myModel.build_generator()
myModel.build_discriminator()

myModel.compile()
myModel.train()
# Out:
# Compile completed
# 1/1 [==============================] - 0s 116ms/step
# epoch: 1/30000, d_loss: 0.54,                 d_acc: 0.59, g_loss: 0.62
# ...
# 1/1 [==============================] - 0s 11ms/step
# epoch: 101/30000, d_loss: 0.03,                 d_acc: 0.98, g_loss: 4.65
# ...
# 1/1 [==============================] - 0s 11ms/step
# epoch: 201/30000, d_loss: 0.47,                 d_acc: 0.72, g_loss: 1.53
# ...
# 1/1 [==============================] - 0s 12ms/step
# epoch: 301/30000, d_loss: 0.70,                 d_acc: 0.50, g_loss: 0.58
# ...
# 1/1 [==============================] - 0s 12ms/step
# epoch: 401/30000, d_loss: 0.68,                 d_acc: 0.50, g_loss: 0.62
# ...
# 1/1 [==============================] - 0s 11ms/step
# epoch: 501/30000, d_loss: 0.67,                 d_acc: 0.48, g_loss: 0.65
# ...
# 1/1 [==============================] - 0s 13ms/step
# epoch: 601/30000, d_loss: 0.66,                 d_acc: 0.53, g_loss: 0.68
# ...
# 1/1 [==============================] - 0s 12ms/step
# ...
