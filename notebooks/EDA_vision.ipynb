# %%
# Change working directory to project root
import os
os.chdir('../')
print(os.getcwd())

# General modules:
import numpy as np
import sys
import random
from datetime import datetime
import pickle
from collections import defaultdict, Counter
import cv2
import re
from scipy.stats import skew, kurtosis

# Exploratory data analysis:
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.image import imread
# %matplotlib inline
import seaborn as sns
from PIL import Image

from classes import EDAHelper, PickleHandler

nat_dir = "/mnt/669118d5-25c6-4d9a-9660-2787d5d59e99/vision_dataset/nat/"
nat_pictures = [os.path.join(nat_dir, file) for file in os.listdir(nat_dir)]

if False:
    statistics_list = []

    for pic in nat_pictures:
        statistics = EDAHelper.calculate_scalar_image_statistics(pic)
        statistics_list.append(statistics)

    df = pd.DataFrame(statistics_list)
    
if False:
    # Carry on adding pictures to df:
    EDAHelper.feedPics('dfTest02', nat_pictures)
    
if True:
    df = PickleHandler.load('data-pickle/dfTest02')
# Out:
# /home/joseca/mat099
# 2023-12-06 00:22:18.687982: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-06 00:22:18.749241: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-06 00:22:18.750830: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-06 00:22:19.805615: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Username: 'test_username'
# Password: 'test_password'

# %%
EDAHelper.plotPicsPerDevice(df)
# Out:
# Device
# D06    132
# D26    150
# D35    154
# D33    155
# D20    159
# D22    163
# D08    168
# D13    171
# D10    178
# D17    188
# D18    204
# D34    204
# D02    204
# D01    205
# D11    207
# D14    209
# D23    210
# D31    216
# D12    216
# D07    217
# D09    217
# D29    224
# D15    227
# D04    227
# D16    235
# D32    236
# D03    237
# D21    253
# D27    254
# D19    259
# D28    266
# D30    271
# D25    287
# D24    312
# D05    350
# Name: count, dtype: int64

# %%
EDAHelper.intensityDistributionPerDevice(df, save = True)

# %%
EDAHelper.intensityBoxPlotPerDevice(df)
